# %% [markdown]
# ## __Import Libraries:__

# %%
# For load and visualisation
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import cv2

# For preprocessing and model building
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import to_categorical
from keras.preprocessing import image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tqdm import tqdm
# %matplotlib inline
from keras.models import model_from_json
from keras.models import load_model

# %% [markdown]
# ## __Loading & Visualising the data:__

# %%
path = 'D:\\IIM Course\\Capstone Project\\Project/'
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'fashion',
#  'fashion.zip',
#  'finalized_model.sav',
#  'IIM-Capstone-Project',
#  'ImgClassification-CustomCNN-Resized-Copy1.ipynb',
#  'ImgClassification-CustomCNN-Resized-Copy2.ipynb',
#  'ImgClassification-CustomCNN-Resized.ipynb',
#  'ImgClassification-CustomCNN.ipynb',
#  'ImgClassification-VGG16.ipynb',
#  'ImgClassificationNOT.ipynb',
#  'model.h5',
#  'model.json',
#  'predictImages',
#  'train.csv',
#  'untitled0.py',
#  'VGG16 Arch..png']

# %%
# Reading .csv file
train_df = pd.read_csv(path + 'train.csv')
train_df.head()
# Out:
#                                                files               target  \
# 0  ../input/fashiondata/data/shoes/5da81ceb7861c2...                shoes
# 1  ../input/fashiondata/data/beauty/5da81d8a7861c...               beauty
# 2  ../input/fashiondata/data/beauty/5da820f26504f...               beauty
# 3  ../input/fashiondata/data/jewelry and watches/...  jewelry and watches
# 4  ../input/fashiondata/data/bags/5da81d2c7861c2a...                 bags
#
#                            images
# 0  5da81ceb7861c2af6a5a89a7_1.jpg
# 1  5da81d8a7861c2af6a5a901c_3.jpg
# 2  5da820f26504fb65da0043e6_0.jpg
# 3  5da81c026504fb65cea700d2_0.jpg
# 4  5da81d2c7861c2af6a5a8c64_2.jpg

# %%
# Get hot-encoded labels for targets
df2 = pd.get_dummies(train_df, columns=['target'])
display(df2)
# Out:
#                                                   files  \
# 0     ../input/fashiondata/data/shoes/5da81ceb7861c2...
# 1     ../input/fashiondata/data/beauty/5da81d8a7861c...
# 2     ../input/fashiondata/data/beauty/5da820f26504f...
# 3     ../input/fashiondata/data/jewelry and watches/...
# 4     ../input/fashiondata/data/bags/5da81d2c7861c2a...
# ...                                                 ...
# 5995  ../input/fashiondata/data/jewelry and watches/...
# 5996  ../input/fashiondata/data/bags/5db81154d5424ee...
# 5997  ../input/fashiondata/data/bags/5da81d547861c2a...
# 5998  ../input/fashiondata/data/beauty/5da81b44b25b0...
# 5999  ../input/fashiondata/data/bags/5db81225d5424ee...
#
#                               images  target_bags  target_beauty  \
# 0     5da81ceb7861c2af6a5a89a7_1.jpg            0              0
# 1     5da81d8a7861c2af6a5a901c_3.jpg            0              1
# 2     5da820f26504fb65da0043e6_0.jpg            0              1
# 3     5da81c026504fb65cea700d2_0.jpg            0              0
# 4     5da81d2c7861c2af6a5a8c64_2.jpg            1              0
# ...                              ...          ...            ...
# 5995  5db865b0d5424ee1f33537b6_2.jpg            0              0
# 5996  5db81154d5424ee1f3352f9c_2.jpg            1              0
# 5997  5da81d547861c2af6a5a8e7d_2.jpg            1              0
# 5998  5da81b44b25b035d1d17a692_6.jpg            0              1
# 5999  5db81225d5424ee1f335361f_0.jpg            1              0
#
#       target_jewelry and watches  target_shoes
# 0                              0             1
# 1                              0             0
# 2                              0             0
# 3                              1             0
# 4                              0             0
# ...                          ...           ...
# 5995                           1             0
# 5996                           0             0
# 5997                           0             0
# 5998                           0             0
# 5999                           0             0
#
# [6000 rows x 6 columns]

# %%
# Separating the hot-encoded columns
df1 = df2.drop(['files', 'images'],axis=1)
display(df1)
# Out:
#       target_bags  target_beauty  target_jewelry and watches  target_shoes
# 0               0              0                           0             1
# 1               0              1                           0             0
# 2               0              1                           0             0
# 3               0              0                           1             0
# 4               1              0                           0             0
# ...           ...            ...                         ...           ...
# 5995            0              0                           1             0
# 5996            1              0                           0             0
# 5997            1              0                           0             0
# 5998            0              1                           0             0
# 5999            1              0                           0             0
#
# [6000 rows x 4 columns]

# %%
# Merge with the original dataset
df = train_df.merge(df1, left_index = True, right_index = True)
display(df)
# Out:
#                                                   files               target  \
# 0     ../input/fashiondata/data/shoes/5da81ceb7861c2...                shoes
# 1     ../input/fashiondata/data/beauty/5da81d8a7861c...               beauty
# 2     ../input/fashiondata/data/beauty/5da820f26504f...               beauty
# 3     ../input/fashiondata/data/jewelry and watches/...  jewelry and watches
# 4     ../input/fashiondata/data/bags/5da81d2c7861c2a...                 bags
# ...                                                 ...                  ...
# 5995  ../input/fashiondata/data/jewelry and watches/...  jewelry and watches
# 5996  ../input/fashiondata/data/bags/5db81154d5424ee...                 bags
# 5997  ../input/fashiondata/data/bags/5da81d547861c2a...                 bags
# 5998  ../input/fashiondata/data/beauty/5da81b44b25b0...               beauty
# 5999  ../input/fashiondata/data/bags/5db81225d5424ee...                 bags
#
#                               images  target_bags  target_beauty  \
# 0     5da81ceb7861c2af6a5a89a7_1.jpg            0              0
# 1     5da81d8a7861c2af6a5a901c_3.jpg            0              1
# 2     5da820f26504fb65da0043e6_0.jpg            0              1
# 3     5da81c026504fb65cea700d2_0.jpg            0              0
# 4     5da81d2c7861c2af6a5a8c64_2.jpg            1              0
# ...                              ...          ...            ...
# 5995  5db865b0d5424ee1f33537b6_2.jpg            0              0
# 5996  5db81154d5424ee1f3352f9c_2.jpg            1              0
# 5997  5da81d547861c2af6a5a8e7d_2.jpg            1              0
# 5998  5da81b44b25b035d1d17a692_6.jpg            0              1
# 5999  5db81225d5424ee1f335361f_0.jpg            1              0
#
#       target_jewelry and watches  target_shoes
# 0                              0             1
# 1                              0             0
# 2                              0             0
# 3                              1             0
# 4                              0             0
# ...                          ...           ...
# 5995                           1             0
# 5996                           0             0
# 5997                           0             0
# 5998                           0             0
# 5999                           0             0
#
# [6000 rows x 7 columns]

# %%
# Drop non-essential column
df = df.drop(['files'],axis=1)
display(df)
# Out:
#                    target                          images  target_bags  \
# 0                   shoes  5da81ceb7861c2af6a5a89a7_1.jpg            0
# 1                  beauty  5da81d8a7861c2af6a5a901c_3.jpg            0
# 2                  beauty  5da820f26504fb65da0043e6_0.jpg            0
# 3     jewelry and watches  5da81c026504fb65cea700d2_0.jpg            0
# 4                    bags  5da81d2c7861c2af6a5a8c64_2.jpg            1
# ...                   ...                             ...          ...
# 5995  jewelry and watches  5db865b0d5424ee1f33537b6_2.jpg            0
# 5996                 bags  5db81154d5424ee1f3352f9c_2.jpg            1
# 5997                 bags  5da81d547861c2af6a5a8e7d_2.jpg            1
# 5998               beauty  5da81b44b25b035d1d17a692_6.jpg            0
# 5999                 bags  5db81225d5424ee1f335361f_0.jpg            1
#
#       target_beauty  target_jewelry and watches  target_shoes
# 0                 0                           0             1
# 1                 1                           0             0
# 2                 1                           0             0
# 3                 0                           1             0
# 4                 0                           0             0
# ...             ...                         ...           ...
# 5995              0                           1             0
# 5996              0                           0             0
# 5997              0                           0             0
# 5998              1                           0             0
# 5999              0                           0             0
#
# [6000 rows x 6 columns]

# %%
# Check for null items
df.isnull().sum().sum()
# Out:
# 0

# %%
# Plot images wrt the given targets
plt.figure(figsize=(10, 10))

for i in range(25):
    ax = plt.subplot(5, 5, i + 1)
    img = mpimg.imread(path + '/fashion/' + df["images"][i])
    img = cv2.resize(img, (224, 224))
    plt.imshow(img)
    plt.title(df["target"][i])
    plt.axis("off")
    
    X = np.array(df)

# %%
# Check names of the columns
train_df.columns
# Out:
# Index(['files', 'target', 'images'], dtype='object')

# %%
# Check names of the new dataframe columns
df.columns
# Out:
# Index(['target', 'images', 'target_bags', 'target_beauty',
#        'target_jewelry and watches', 'target_shoes'],
#       dtype='object')

# %%
# Check unique columns
df['target'].unique()
# Out:
# array(['shoes', 'beauty', 'jewelry and watches', 'bags'], dtype=object)

# %%
# Countplot to check if data has equal shape
sns.countplot(df['target'])

# %%
# Count to check if data has equal sape
df["target"].value_counts()
# Out:
# beauty                 1524
# bags                   1508
# jewelry and watches    1503
# shoes                  1465
# Name: target, dtype: int64

# %% [markdown]
# ## __Preprocessing of the data:__

# %%
# Preprocessing the data
train_image = []
for i in tqdm(range(df.shape[0])):
    img = image.load_img(path + '/fashion/' +df['images'][i],target_size=(320,320,3))
    img = image.img_to_array(img)
    img = img/255
    train_image.append(img)
X = np.array(train_image)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 6000/6000 [00:29<00:00, 203.49it/s]

# %%
# Shape of the array
X.shape
# Out:
# (6000, 320, 320, 3)

# %%
# Plot and visualize preprocessed image
plt.imshow(X[2])

# %%
# Plot and visualize preprocessed image
df['target'][2]
# Out:
# 'beauty'

# %%
y = np.array(df.drop(['target', 'images'],axis=1))
y.shape
# Out:
# (6000, 4)

# %% [markdown]
# ## __Defining the architecture of the model:__

# %%
# Randomly separate 10% of the images as our validation set
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.1)

# %%
# Define the architecture of our model
# 
model = Sequential()
# Layer1
model.add(Conv2D(filters=16, kernel_size=(5, 5), activation="relu", input_shape=(320,320,3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Layer2
model.add(Conv2D(filters=32, kernel_size=(5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Layer3
model.add(Conv2D(filters=64, kernel_size=(5, 5), activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Layer4
model.add(Conv2D(filters=64, kernel_size=(5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Defining output layer with Neurons
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4, activation='sigmoid'))

# %%
# Summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 316, 316, 16)      1216
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 158, 158, 16)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 158, 158, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 154, 154, 32)      12832
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 77, 77, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 77, 77, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 73, 73, 64)        51264
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        102464
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               2097280
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 2,273,572
# Trainable params: 2,273,572
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Training the model.
history = model.fit(X_train, y_train, epochs=20, validation_data=(X_test, y_test), batch_size=64)
# Out:
# Epoch 1/20
# 85/85 [==============================] - 965s 11s/step - loss: 0.6248 - accuracy: 0.2747 - val_loss: 0.5816 - val_accuracy: 0.2733
# Epoch 2/20
# 85/85 [==============================] - 932s 11s/step - loss: 0.5237 - accuracy: 0.4580 - val_loss: 0.5052 - val_accuracy: 0.6300
# Epoch 3/20
# 85/85 [==============================] - 931s 11s/step - loss: 0.4625 - accuracy: 0.5643 - val_loss: 0.4287 - val_accuracy: 0.6850
# Epoch 4/20
# 85/85 [==============================] - 935s 11s/step - loss: 0.4067 - accuracy: 0.6477 - val_loss: 0.3649 - val_accuracy: 0.6983
# Epoch 5/20
# 85/85 [==============================] - 940s 11s/step - loss: 0.3506 - accuracy: 0.7117 - val_loss: 0.3841 - val_accuracy: 0.6517
# Epoch 6/20
# 85/85 [==============================] - 985s 12s/step - loss: 0.3047 - accuracy: 0.7550 - val_loss: 0.3406 - val_accuracy: 0.7367
# Epoch 7/20
# 85/85 [==============================] - 1048s 12s/step - loss: 0.2826 - accuracy: 0.7688 - val_loss: 0.3031 - val_accuracy: 0.7700
# Epoch 8/20
# 85/85 [==============================] - 1059s 12s/step - loss: 0.2696 - accuracy: 0.7923 - val_loss: 0.2954 - val_accuracy: 0.7567
# Epoch 9/20
# 85/85 [==============================] - 916s 11s/step - loss: 0.2237 - accuracy: 0.8349 - val_loss: 0.1984 - val_accuracy: 0.8600
# Epoch 10/20
# 85/85 [==============================] - 880s 10s/step - loss: 0.1895 - accuracy: 0.8507 - val_loss: 0.2214 - val_accuracy: 0.8383
# Epoch 11/20
# 85/85 [==============================] - 881s 10s/step - loss: 0.1756 - accuracy: 0.8651 - val_loss: 0.1741 - val_accuracy: 0.8717
# Epoch 12/20
# 85/85 [==============================] - 882s 10s/step - loss: 0.1641 - accuracy: 0.8735 - val_loss: 0.2136 - val_accuracy: 0.8483
# Epoch 13/20
# 85/85 [==============================] - 883s 10s/step - loss: 0.1560 - accuracy: 0.8766 - val_loss: 0.1618 - val_accuracy: 0.8750
# Epoch 14/20
# 85/85 [==============================] - 882s 10s/step - loss: 0.1271 - accuracy: 0.9028 - val_loss: 0.2023 - val_accuracy: 0.8567
# Epoch 15/20
# 85/85 [==============================] - 897s 11s/step - loss: 0.1580 - accuracy: 0.8756 - val_loss: 0.2360 - val_accuracy: 0.8317
# Epoch 16/20
# 85/85 [==============================] - 831s 10s/step - loss: 0.1558 - accuracy: 0.8795 - val_loss: 0.2889 - val_accuracy: 0.7583
# Epoch 17/20
# 85/85 [==============================] - 811s 10s/step - loss: 0.1083 - accuracy: 0.9148 - val_loss: 0.1912 - val_accuracy: 0.8617
# Epoch 18/20
# 85/85 [==============================] - 842s 10s/step - loss: 0.1074 - accuracy: 0.9205 - val_loss: 0.1507 - val_accuracy: 0.8950
# Epoch 19/20
# 85/85 [==============================] - 916s 11s/step - loss: 0.1046 - accuracy: 0.9205 - val_loss: 0.2291 - val_accuracy: 0.8083
# Epoch 20/20
# 85/85 [==============================] - 917s 11s/step - loss: 0.1022 - accuracy: 0.9277 - val_loss: 0.1675 - val_accuracy: 0.8800

# %%
# Took ~3 hours for training
# serialize model to JSON
model_json = model.to_json()
with open("model_resized320.json", "w") as json_file:
    json_file.write(model_json)

# Save weights to HDF5
model.save("model_resized320.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# evaluate the test set
scores = model.evaluate(X_test, y_test, verbose=0)
print("Final test %s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# evaluate the train set
scores = model.evaluate(X_train, y_train, verbose=0)
print("Final train %s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# Final test accuracy: 88.00%
# Final train accuracy: 95.24%

# %%
# load model
#model = load_model('model.h5')
#print("Loaded model from disk")

# load json and create model
json_file = open('model_resized.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
loaded_model.load_weights("model_resized.h5")
print("Loaded model from disk")

#f = open ('model.json', "r")
#data = json.loads(f.read())
#data

# evaluate the test set
history = loaded_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

scores = loaded_model.evaluate(X_test, y_test, verbose=0)
print("Final test %s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# evaluate the train set
scores = loaded_model.evaluate(X_train, y_train, verbose=0)
print("Final train %s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

# %% [markdown]
# ## __Testing the made arcitecture:__

# %%
img = image.load_img(path + '/predictImages/' +'prod2.jpg',target_size=(320,320,3))
img = image.img_to_array(img)
img = img/255

# %%
classes = np.array(df.columns[2:])
proba = model.predict(img.reshape(1,320,320,3))
among4 = np.argsort(proba[0])[:-5:-1]
for i in range(4):
    print("{}".format(classes[among4[i]])+" ({:.3})".format(proba[0][among4[i]]))
plt.imshow(img)
# Out:
# target_beauty (0.998)
# target_bags (0.00205)
# target_shoes (9.35e-05)
# target_jewelry and watches (6.96e-05)
