# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import cv2

# %%
path = 'D:\\IIM Course\\Capstone Project\\Project/'
os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'fashion',
#  'fashion.zip',
#  'IIM-Capstone-Project',
#  'ImgClassification.ipynb',
#  'predictImages',
#  'train.csv',
#  'Untitled.ipynb',
#  'untitled0.py']

# %%
train_df = pd.read_csv(path + 'train.csv')
train_df.head()
# Out:
#                                                files               target  \
# 0  ../input/fashiondata/data/shoes/5da81ceb7861c2...                shoes
# 1  ../input/fashiondata/data/beauty/5da81d8a7861c...               beauty
# 2  ../input/fashiondata/data/beauty/5da820f26504f...               beauty
# 3  ../input/fashiondata/data/jewelry and watches/...  jewelry and watches
# 4  ../input/fashiondata/data/bags/5da81d2c7861c2a...                 bags
#
#                            images
# 0  5da81ceb7861c2af6a5a89a7_1.jpg
# 1  5da81d8a7861c2af6a5a901c_3.jpg
# 2  5da820f26504fb65da0043e6_0.jpg
# 3  5da81c026504fb65cea700d2_0.jpg
# 4  5da81d2c7861c2af6a5a8c64_2.jpg

# %%
# Get hot-encoded labels for targets
df2 = pd.get_dummies(train_df, columns=['target'])
display(df2)
# Out:
#                                                   files  \
# 0     ../input/fashiondata/data/shoes/5da81ceb7861c2...
# 1     ../input/fashiondata/data/beauty/5da81d8a7861c...
# 2     ../input/fashiondata/data/beauty/5da820f26504f...
# 3     ../input/fashiondata/data/jewelry and watches/...
# 4     ../input/fashiondata/data/bags/5da81d2c7861c2a...
# ...                                                 ...
# 5995  ../input/fashiondata/data/jewelry and watches/...
# 5996  ../input/fashiondata/data/bags/5db81154d5424ee...
# 5997  ../input/fashiondata/data/bags/5da81d547861c2a...
# 5998  ../input/fashiondata/data/beauty/5da81b44b25b0...
# 5999  ../input/fashiondata/data/bags/5db81225d5424ee...
#
#                               images  target_bags  target_beauty  \
# 0     5da81ceb7861c2af6a5a89a7_1.jpg            0              0
# 1     5da81d8a7861c2af6a5a901c_3.jpg            0              1
# 2     5da820f26504fb65da0043e6_0.jpg            0              1
# 3     5da81c026504fb65cea700d2_0.jpg            0              0
# 4     5da81d2c7861c2af6a5a8c64_2.jpg            1              0
# ...                              ...          ...            ...
# 5995  5db865b0d5424ee1f33537b6_2.jpg            0              0
# 5996  5db81154d5424ee1f3352f9c_2.jpg            1              0
# 5997  5da81d547861c2af6a5a8e7d_2.jpg            1              0
# 5998  5da81b44b25b035d1d17a692_6.jpg            0              1
# 5999  5db81225d5424ee1f335361f_0.jpg            1              0
#
#       target_jewelry and watches  target_shoes
# 0                              0             1
# 1                              0             0
# 2                              0             0
# 3                              1             0
# 4                              0             0
# ...                          ...           ...
# 5995                           1             0
# 5996                           0             0
# 5997                           0             0
# 5998                           0             0
# 5999                           0             0
#
# [6000 rows x 6 columns]

# %%
# Separating the hot-encoded columns
df1 = df2.drop(['files', 'images'],axis=1)
display(df1)
# Out:
#       target_bags  target_beauty  target_jewelry and watches  target_shoes
# 0               0              0                           0             1
# 1               0              1                           0             0
# 2               0              1                           0             0
# 3               0              0                           1             0
# 4               1              0                           0             0
# ...           ...            ...                         ...           ...
# 5995            0              0                           1             0
# 5996            1              0                           0             0
# 5997            1              0                           0             0
# 5998            0              1                           0             0
# 5999            1              0                           0             0
#
# [6000 rows x 4 columns]

# %%
# Merge with the original dataset
df = train_df.merge(df1, left_index = True, right_index = True)
display(df)
# Out:
#                                                   files               target  \
# 0     ../input/fashiondata/data/shoes/5da81ceb7861c2...                shoes
# 1     ../input/fashiondata/data/beauty/5da81d8a7861c...               beauty
# 2     ../input/fashiondata/data/beauty/5da820f26504f...               beauty
# 3     ../input/fashiondata/data/jewelry and watches/...  jewelry and watches
# 4     ../input/fashiondata/data/bags/5da81d2c7861c2a...                 bags
# ...                                                 ...                  ...
# 5995  ../input/fashiondata/data/jewelry and watches/...  jewelry and watches
# 5996  ../input/fashiondata/data/bags/5db81154d5424ee...                 bags
# 5997  ../input/fashiondata/data/bags/5da81d547861c2a...                 bags
# 5998  ../input/fashiondata/data/beauty/5da81b44b25b0...               beauty
# 5999  ../input/fashiondata/data/bags/5db81225d5424ee...                 bags
#
#                               images  target_bags  target_beauty  \
# 0     5da81ceb7861c2af6a5a89a7_1.jpg            0              0
# 1     5da81d8a7861c2af6a5a901c_3.jpg            0              1
# 2     5da820f26504fb65da0043e6_0.jpg            0              1
# 3     5da81c026504fb65cea700d2_0.jpg            0              0
# 4     5da81d2c7861c2af6a5a8c64_2.jpg            1              0
# ...                              ...          ...            ...
# 5995  5db865b0d5424ee1f33537b6_2.jpg            0              0
# 5996  5db81154d5424ee1f3352f9c_2.jpg            1              0
# 5997  5da81d547861c2af6a5a8e7d_2.jpg            1              0
# 5998  5da81b44b25b035d1d17a692_6.jpg            0              1
# 5999  5db81225d5424ee1f335361f_0.jpg            1              0
#
#       target_jewelry and watches  target_shoes
# 0                              0             1
# 1                              0             0
# 2                              0             0
# 3                              1             0
# 4                              0             0
# ...                          ...           ...
# 5995                           1             0
# 5996                           0             0
# 5997                           0             0
# 5998                           0             0
# 5999                           0             0
#
# [6000 rows x 7 columns]

# %%
# Drop non-essential column
df = df.drop(['files'],axis=1)
display(df)
# Out:
#                    target                          images  target_bags  \
# 0                   shoes  5da81ceb7861c2af6a5a89a7_1.jpg            0
# 1                  beauty  5da81d8a7861c2af6a5a901c_3.jpg            0
# 2                  beauty  5da820f26504fb65da0043e6_0.jpg            0
# 3     jewelry and watches  5da81c026504fb65cea700d2_0.jpg            0
# 4                    bags  5da81d2c7861c2af6a5a8c64_2.jpg            1
# ...                   ...                             ...          ...
# 5995  jewelry and watches  5db865b0d5424ee1f33537b6_2.jpg            0
# 5996                 bags  5db81154d5424ee1f3352f9c_2.jpg            1
# 5997                 bags  5da81d547861c2af6a5a8e7d_2.jpg            1
# 5998               beauty  5da81b44b25b035d1d17a692_6.jpg            0
# 5999                 bags  5db81225d5424ee1f335361f_0.jpg            1
#
#       target_beauty  target_jewelry and watches  target_shoes
# 0                 0                           0             1
# 1                 1                           0             0
# 2                 1                           0             0
# 3                 0                           1             0
# 4                 0                           0             0
# ...             ...                         ...           ...
# 5995              0                           1             0
# 5996              0                           0             0
# 5997              0                           0             0
# 5998              1                           0             0
# 5999              0                           0             0
#
# [6000 rows x 6 columns]

# %%
# Check for null items
df.isnull().sum().sum()
# Out:
# 0

# %%
# Plot images wrt the given targets
plt.figure(figsize=(10, 10))

for i in range(25):
    ax = plt.subplot(5, 5, i + 1)
    img = mpimg.imread(path + '/fashion/' + df["images"][i])
    img = cv2.resize(img, (224, 224))
    plt.imshow(img)
    plt.title(df["target"][i])
    plt.axis("off")
    
    X = np.array(df)

# %%
# Check names of the columns
train_df.columns
# Out:
# Index(['files', 'target', 'images'], dtype='object')

# %%
# Check names of the new dataframe columns
df.columns
# Out:
# Index(['target', 'images', 'target_bags', 'target_beauty',
#        'target_jewelry and watches', 'target_shoes'],
#       dtype='object')

# %%
# Check unique columns
df['target'].unique()
# Out:
# array(['shoes', 'beauty', 'jewelry and watches', 'bags'], dtype=object)

# %%
# Countplot to check if data has equal shape
sns.countplot(df['target'])

# %%
# Count to check if data has equal sape
df["target"].value_counts()
# Out:
# beauty                 1524
# bags                   1508
# jewelry and watches    1503
# shoes                  1465
# Name: target, dtype: int64

# %%
from tqdm import tqdm
from keras.preprocessing import image

# %%
# Loading and Preprocessing the data
train_image = []
for i in tqdm(range(df.shape[0])):
    img = image.load_img(path + '/fashion/' +df['images'][i],target_size=(224,224,3))
    img = image.img_to_array(img)
    img = img/255
    train_image.append(img)
X = np.array(train_image)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 6000/6000 [00:20<00:00, 291.53it/s]

# %%
# Shape of the array
X.shape
# Out:
# (6000, 224, 224, 3)

# %%
# Plot and visualize preprocessed image
plt.imshow(X[2])

# %%
# Plot and visualize preprocessed image
df['target'][2]
# Out:
# 'beauty'

# %%
y = np.array(df.drop(['target', 'images'],axis=1))
y.shape
# Out:
# (6000, 4)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import to_categorical
from keras.preprocessing import image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tqdm import tqdm
# %matplotlib inline

# %%
# Randomly separate 10% of the images as our validation set
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.1)

# %%
# Define the architecture of our model
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=(5, 5), activation="relu", input_shape=(224,224,3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(filters=32, kernel_size=(5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(filters=64, kernel_size=(5, 5), activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(filters=64, kernel_size=(5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4, activation='sigmoid'))

# %%
# Summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 220, 220, 16)      1216
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 110, 110, 16)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 110, 110, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 106, 106, 32)      12832
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 53, 53, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 53, 53, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 49, 49, 64)        51264
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        102464
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 10, 10, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               819328
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 995,620
# Trainable params: 995,620
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Training the model.
model.fit(X_train, y_train, epochs=20, validation_data=(X_test, y_test), batch_size=64)
# Out:
# Epoch 1/20
# 85/85 [==============================] - 413s 5s/step - loss: 0.6084 - accuracy: 0.2864 - val_loss: 0.5238 - val_accuracy: 0.5117
# Epoch 2/20
# 85/85 [==============================] - 413s 5s/step - loss: 0.5143 - accuracy: 0.4719 - val_loss: 0.4632 - val_accuracy: 0.6100
# Epoch 3/20
# 85/85 [==============================] - 422s 5s/step - loss: 0.4538 - accuracy: 0.5810 - val_loss: 0.4250 - val_accuracy: 0.6550
# Epoch 4/20
# 85/85 [==============================] - 419s 5s/step - loss: 0.4075 - accuracy: 0.6444 - val_loss: 0.3590 - val_accuracy: 0.7417
# Epoch 5/20
# 85/85 [==============================] - 423s 5s/step - loss: 0.3645 - accuracy: 0.7069 - val_loss: 0.3486 - val_accuracy: 0.7350
# Epoch 6/20
# 85/85 [==============================] - 420s 5s/step - loss: 0.3265 - accuracy: 0.7357 - val_loss: 0.2814 - val_accuracy: 0.7950
# Epoch 7/20
# 85/85 [==============================] - 422s 5s/step - loss: 0.2750 - accuracy: 0.7890 - val_loss: 0.2280 - val_accuracy: 0.8300
# Epoch 8/20
# 85/85 [==============================] - 420s 5s/step - loss: 0.2414 - accuracy: 0.8154 - val_loss: 0.2515 - val_accuracy: 0.8067
# Epoch 9/20
# 85/85 [==============================] - 421s 5s/step - loss: 0.2398 - accuracy: 0.8151 - val_loss: 0.1876 - val_accuracy: 0.8700
# Epoch 10/20
# 85/85 [==============================] - 423s 5s/step - loss: 0.2067 - accuracy: 0.8445 - val_loss: 0.2118 - val_accuracy: 0.8333
# Epoch 11/20
# 85/85 [==============================] - 408s 5s/step - loss: 0.1940 - accuracy: 0.8562 - val_loss: 0.1731 - val_accuracy: 0.8750
# Epoch 12/20
# 85/85 [==============================] - 403s 5s/step - loss: 0.1706 - accuracy: 0.8751 - val_loss: 0.1639 - val_accuracy: 0.8700
# Epoch 13/20
# 85/85 [==============================] - 403s 5s/step - loss: 0.1629 - accuracy: 0.8755 - val_loss: 0.1456 - val_accuracy: 0.8867
# Epoch 14/20
# 85/85 [==============================] - 403s 5s/step - loss: 0.1647 - accuracy: 0.8731 - val_loss: 0.1594 - val_accuracy: 0.8917
# Epoch 15/20
# 85/85 [==============================] - 402s 5s/step - loss: 0.1430 - accuracy: 0.8934 - val_loss: 0.1450 - val_accuracy: 0.8983
# Epoch 16/20
# 85/85 [==============================] - 402s 5s/step - loss: 0.1279 - accuracy: 0.9009 - val_loss: 0.1441 - val_accuracy: 0.9033
# Epoch 17/20
# 85/85 [==============================] - 402s 5s/step - loss: 0.1400 - accuracy: 0.8956 - val_loss: 0.1375 - val_accuracy: 0.8883
# Epoch 18/20
# 85/85 [==============================] - 402s 5s/step - loss: 0.1272 - accuracy: 0.9099 - val_loss: 0.1318 - val_accuracy: 0.9033
# Epoch 19/20
# 85/85 [==============================] - 401s 5s/step - loss: 0.1182 - accuracy: 0.9137 - val_loss: 0.1499 - val_accuracy: 0.8983
# Epoch 20/20
# 85/85 [==============================] - 405s 5s/step - loss: 0.1280 - accuracy: 0.9044 - val_loss: 0.1374 - val_accuracy: 0.8950

# %%
# Save model
model.save("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# load model
#model = load_model('model.h5')

# %%
# Plot history: Loss
plt.plot(model.model['val_loss'])
plt.title('Validation loss')
plt.ylabel('Loss value')
plt.xlabel('No. epoch')
plt.show()

# Plot history: Val Accuracy
plt.plot(model.model['val_accuracy'])
plt.title('Validation accuracy')
plt.ylabel('Accuracy value (%)')
plt.xlabel('No. epoch')
plt.show()

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)

print("Final test accuracy: ", test_acc)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-210-3e64625d3953> in <module>
#       1 # Plot history: Loss
# ----> 2 plt.plot(model.model['val_loss'])
#       3 plt.title('Validation loss')
#       4 plt.ylabel('Loss value')
#       5 plt.xlabel('No. epoch')
#
# AttributeError: 'Sequential' object has no attribute 'model'

# %%
# evaluate the test set
scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 89.50%

# %%
# evaluate the train set
scores = model.evaluate(X_train, y_train, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 96.19%

# %%
img = image.load_img(path + '/predictImages/' +'bag3.jpg',target_size=(224,224,3))
img = image.img_to_array(img)
img = img/255

# %%
classes = np.array(df.columns[2:])
proba = model.predict(img.reshape(1,224,224,3))
among4 = np.argsort(proba[0])[:-5:-1]
for i in range(4):
    print("{}".format(classes[among4[i]])+" ({:.3})".format(proba[0][among4[i]]))
plt.imshow(img)
# Out:
# target_bags (0.636)
# target_jewelry and watches (0.322)
# target_beauty (0.0337)
# target_shoes (0.0164)
